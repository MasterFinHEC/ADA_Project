# %%
# Import packages
import sys
# !{sys.executable} -m pip install world_bank_data
# !{sys.executable} -m pip install xlrd
import pandas as pd
import world_bank_data as wb
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import calendar
# %matplotlib inline

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# Out:
# Processing c:\users\benjamin\appdata\local\pip\cache\wheels\ce\e4\2c\da5faef202dbc9c70b4572e80b98b2fc7de5e098c16af61ce1\world_bank_data-0.1.3-cp37-none-any.whl
# Requirement already satisfied: requests in c:\users\benjamin\anaconda3\lib\site-packages (from world_bank_data) (2.22.0)
# Collecting cachetools
#   Using cached cachetools-4.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pandas in c:\users\benjamin\anaconda3\lib\site-packages (from world_bank_data) (1.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\benjamin\anaconda3\lib\site-packages (from requests->world_bank_data) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\benjamin\anaconda3\lib\site-packages (from requests->world_bank_data) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\benjamin\anaconda3\lib\site-packages (from requests->world_bank_data) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\benjamin\anaconda3\lib\site-packages (from requests->world_bank_data) (1.25.8)
# Requirement already satisfied: pytz>=2017.2 in c:\users\benjamin\anaconda3\lib\site-packages (from pandas->world_bank_data) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\benjamin\anaconda3\lib\site-packages (from pandas->world_bank_data) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\benjamin\anaconda3\lib\site-packages (from pandas->world_bank_data) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\benjamin\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->world_bank_data) (1.14.0)
# Installing collected packages: cachetools, world-bank-data
# Successfully installed cachetools-4.1.0 world-bank-data-0.1.3
# Requirement already satisfied: xlrd in c:\users\benjamin\anaconda3\lib\site-packages (1.2.0)

# %% [markdown]
# ### 1. Get Data from John Hopkins

# %%
# Loading Covid 19 Data
public_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
corona_data = pd.read_csv(public_url)
corona_data.drop(['Lat','Long','Province/State'],axis=1)
countries = sorted(corona_data['Country/Region'].unique())
country_data = corona_data.groupby('Country/Region').sum()
country_data = country_data.drop(['Lat','Long'],axis=1)
country_data = country_data.rename(columns={'Country/Region':'Country'},index={'US':'United States'})

# %% [markdown]
# ### 2. Get Data from the World Bank

# %%
# Get GDP data
GDP = pd.DataFrame(wb.get_series('NY.GDP.MKTP.CD',mrv=1))
GDP = GDP.droplevel(level=[1,2]) # Droping multi level indexing

# Get gini Index
Gini = pd.DataFrame(wb.get_series('SI.POV.GINI',date = '2010'))
Gini = Gini.droplevel(level=[1,2]) # Droping multi level indexing

# Get population data
Pop = pd.DataFrame(wb.get_series('SP.POP.TOTL',mrv=1))
Pop = Pop.droplevel(level=[1,2]) # Droping multi level indexing

# Get Health System Data
Health = pd.DataFrame(wb.get_series('SH.MED.BEDS.ZS',date = '2010'))
Health = Health.droplevel(level=[1,2]) # Droping multi level indexing

# Get Density Data
Dens = pd.DataFrame(wb.get_series('EN.POP.DNST',mrv=1))
Dens = Dens.droplevel(level=[1,2])

# Get Trade data
Trade = pd.DataFrame(wb.get_series('NE.TRD.GNFS.ZS',mrv=1))
Trade = Trade.droplevel(level=[1,2])

# %% [markdown]
# ### Religion Data

# %%
religion = pd.read_excel('Data/religious-diversity-index.xlsx')
religion = religion.set_index('Country')
# Out:
# Index(['RDI', 'Percent Christian', 'Percent Muslim', 'Percent Unaffiliated',
#        'Percent Hindu', 'Percent Buddhist', 'Percent Folk Religions',
#        'Percent Other Religions', 'Percent Jewish', '2010 Country Population'],
#       dtype='object')

# %% [markdown]
# RDI score, higher diversity

# %% [markdown]
# ### Downloaded Data

# %%
# Economist businnes unit
df = pd.read_excel('Data/_EIU-Democracy Indices - Dataset - v3.xlsx')
year = df['time'] == 2018
DEM = df[year]
DEM = DEM.drop(['geo','a','b','c','d','e','time','f'],axis = 1)
DEM = DEM.set_index('name')
DEM = DEM.rename(columns={'name':'Country'})

# Continent data
Cont = pd.read_csv('Data/Countries-Continents.csv')
Cont = Cont.set_index('Country')
Cont = Cont.rename(index={'US':'United States'})

# %% [markdown]
# ### 4. Merge all data

# %%
allData = country_data.join([GDP,Gini,DEM,Pop,Health,Dens,Trade,religion,Cont])
allData = allData.dropna()

# %% [markdown]
# ### 5. Plot

# %% [markdown]
# a. Confirmed Cases

# %%
countries = ['France','Switzerland','Germany','China','Spain','Italy']

fig = plt.figure(figsize=(27,9))
plt.subplot(221)
for country in countries:
    toplot = country_data.loc[country,:]
    plt.plot(toplot)
plt.legend(countries)
plt.xticks(np.linspace(0,len(allData.columns)-1,5), calendar.month_name[1:5], rotation=20)
plt.ylabel('Number of cases')
plt.subplot(222)
for country in countries:
    toplot = country_data.loc[country,:]/allData.loc[country,'SP.POP.TOTL']*100
    plt.plot(toplot)
plt.legend(countries)
plt.xticks(np.linspace(0,len(allData.columns)-1,5), calendar.month_name[1:5], rotation=20)
plt.ylabel('% of population')
plt.subplot(223)
for country in countries:
    toplot = []
    for time in range(len(country_data.columns)-4):
        if country_data.loc[country,country_data.columns[time]] != 0:
            for flat in range(0,4): 
                meanGrowth = 0
                Growth = (country_data.loc[country,country_data.columns[time+1+flat]]/
                      country_data.loc[country,country_data.columns[time+flat]] - 1)*100
                meanGrowth = meanGrowth + Growth
                if meanGrowth > 200:
                    meanGrowth = 200
            toplot.append(meanGrowth/4)
        else:
            toplot.append(0)
    plt.plot(toplot)
plt.legend(countries)
plt.xticks(np.linspace(0,len(allData.columns)-1,5), calendar.month_name[1:5], rotation=20)
plt.ylabel('% of growth')
plt.subplot(224)
for country in countries:
    toplot = []
    for time in range(len(country_data.columns)-1):
        toplot.append(country_data.loc[country,country_data.columns[time+1]]-
        country_data.loc[country,country_data.columns[time]])
    plt.hist(toplot,bins=20)
plt.legend(countries)
plt.xlim([0,12000])
#plt.xticks(np.linspace(0,len(allData.columns)-1,5), calendar.month_name[1:5], rotation=20)
plt.ylabel('Frequency')
plt.xlabel('New cases per day')
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# b. all countries

# %%
#Bar plot of the new cases
fig = plt.figure(figsize=[18,6])
graph = []
graph2 = []
for time in range(len(country_data.columns)-1):
    value = 0
    for country in allData.index:
        toplot = (country_data.loc[country,country_data.columns[time+1]]-country_data.loc[country,country_data.columns[time]])
        value = value  + toplot
    graph.append(value)
date = pd.date_range(start="2020-02-22",end="2020-04-16")
plt.bar(np.linspace(0,len(graph),len(graph)),np.asarray(graph))
plt.title('Total world new cases per day')
fig.set_facecolor('lightgrey')
plt.ylabel('New cases')
plt.xlabel('Days since first case in Wuhan')
plt.legend('World Cases')
for time in range(len(country_data.columns)-10):
    for country in allData.index:
        for flat in range(0,10):
            toplot = (country_data.loc[country,country_data.columns[time+1+flat]]-country_data.loc[country,country_data.columns[time+flat]])
            value = value  + toplot
        graph2.append(value/10)
plt.plot(graph,color='orange')
plt.legend(['World Cases','10 days rolling average'])
plt.show()

# %% [markdown]
# c. Geographical repartion

# %%
Continents = allData.loc[:,'Continent'].unique()
count = []
for continent in Continents:
    condObj = allData.apply(lambda x: True if x['Continent'] == continent else False, axis =1)
    count.append(len(condObj[condObj == True].index))
    

# Data to plot
labels = Continents
sizes = count
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','orange','lightgrey']
explode = (0, 0, 0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Geographical repartition of avaiable data')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Splitting the predictors and target

# %%
y = allData.drop(['NY.GDP.MKTP.CD', 'SI.POV.GINI', 'Democracy index (EIU)', 'SP.POP.TOTL', 'SH.MED.BEDS.ZS',
                  'EN.POP.DNST', 'NE.TRD.GNFS.ZS','Continent','RDI', 'Percent Christian', 'Percent Muslim', 
                  'Percent Unaffiliated','Percent Hindu','Percent Buddhist', 'Percent Folk Religions',
                'Percent Other Religions', 'Percent Jewish', '2010 Country Population'],axis = 1)

X = allData.loc[:,['NY.GDP.MKTP.CD', 'SI.POV.GINI', 'Democracy index (EIU)', 'SP.POP.TOTL', 'SH.MED.BEDS.ZS',
                   'EN.POP.DNST', 'NE.TRD.GNFS.ZS','RDI', 'Percent Christian', 'Percent Muslim', 
                  'Percent Unaffiliated','Percent Hindu', 'Percent Buddhist', 'Percent Folk Religions',
                'Percent Other Religions', 'Percent Jewish','Continent']] # Drop the second population index

# %% [markdown]
# ### Finding first cases

# %%
nonZero = []
for country in y.index:
    for date in y.columns:
        if y.loc[country,date] != 0:
            index = y.columns.get_loc(date)
            nonZero.append(index)
            break
frac = y.iloc[:,-1]/X.loc[:,'SP.POP.TOTL']*100
fig = plt.figure(figsize=[12,6])
plt.plot(nonZero,frac,'.')
plt.title('First Cases in each country')
plt.xlabel('Days since first case in Wuhan')
plt.ylabel('Percent of population with Covid at 20.04.2020')

count = 0
for x,z in zip(nonZero,frac):
    
    label = y.index[count]

    plt.annotate(label, # this is the text
                 (x,z), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
    count += 1
plt.axvline(x = 13)
plt.axvline(x = 30)
plt.show()

# %%
# Splitting the data
RanInd = np.random.permutation(y.index)
y_train = y.loc[RanInd[0:40],:]
y_test = y.loc[RanInd[41:-1],:]
x_train = X.loc[RanInd[0:40],:]
x_test = X.loc[RanInd[41:-1],:]

# Predicting the value
from sklearn.gaussian_process import GaussianProcessRegressor

RBF = GaussianProcessRegressor()
RBF.fit(x_train,y_train)
y_predict = RBF.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-9b6c37eb42cc> in <module>
#      10
#      11 RBF = GaussianProcessRegressor()
# ---> 12 RBF.fit(x_train,y_train)
#      13 y_predict = RBF.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\gaussian_process\_gpr.py in fit(self, X, y)
#     189         if self.kernel_.requires_vector_input:
#     190             X, y = check_X_y(X, y, multi_output=True, y_numeric=True,
# --> 191                              ensure_2d=True, dtype="numeric")
#     192         else:
#     193             X, y = check_X_y(X, y, multi_output=True, y_numeric=True,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float:
# Luxembourg              0.0      0.0      0.0      0.0  ...
# Madagascar              0.0      0.0      0.0      0.0  ...
# Malta                   0.0      0.0      0.0      0.0  ...
# Mexico                  0.0      0.0      0.0      0.0  ...
# Moldova                 0.0      0.0      0.0      0.0  ...
# Mongolia                0.0      0.0      0.0      0.0  ...
# Norway                  0.0      0.0      0.0      0.0  ...
# Pakistan                0.0      0.0      0.0      0.0  ...
# Paraguay                0.0      0.0      0.0      0.0  ...
# Peru                    0.0      0.0      0.0      0.0  ...
# Poland                  0.0      0.0      0.0      0.0  ...
# Portugal                0.0      0.0      0.0      0.0  ...
# Romania                 0.0      0.0      0.0      0.0  ...
# Slovenia                0.0      0.0      0.0      0.0  ...
# Spain                   0.0      0.0      0.0      0.0  ...
# Sweden                  0.0      0.0      0.0      1.0  ...
# Switzerland             0.0      0.0      0.0      0.0  ...
# Thailand               14.0     14.0     14.0     19.0  ...
# Tunisia                 0.0      0.0      0.0      0.0  ...
# Turkey                  0.0      0.0      0.0      0.0  ...
# United States           5.0      5.0      5.0      7.0  ...
# Ukraine                 0.0      0.0      0.0      0.0  ...
# United Kingdom          0.0      0.0      0.0      2.0  ...
# Uruguay                 0.0      0.0      0.0      0.0  ...
# Vietnam                 2.0      2.0      2.0      2.0  ...
# Zambia                  0.0      0.0      0.0      0.0  ...
#
#                     Percent Christian  Percent Muslim  Percent Unaffiliated  \
# Country/Region
# Argentina                       0.852            0.01                 0.122
# Armenia                         0.985          < 0.1%                 0.013
# Australia                       0.673           0.024                 0.242
# Austria                         0.804           0.054                 0.135
# Belarus                         0.712           0.002                 0.286
# Belgium                         0.642           0.059                  0.29
# Bulgaria                        0.821           0.137                 0.042
# Canada                           0.69           0.021                 0.237
# China                           0.051           0.018                 0.522
# Costa Rica                      0.909          < 0.1%                 0.079
# Croatia                         0.934           0.014                 0.051
# Cyprus                          0.732           0.253                 0.012
# Denmark                         0.835           0.041                 0.118
# Dominican Republic               0.88          < 0.1%                 0.109
# Ecuador                         0.941          < 0.1%                 0.055
# El Salvador                     0.882          < 0.1%                  0.11
# Estonia                         0.399           0.002                 0.596
# Finland                         0.816           0.008                 0.176
# France                           0.63           0.075                  0.28
# Georgia                         0.885           0.107                 0.007
# Germany                         0.687           0.058                 0.247
# Greece                          0.881           0.053                 0.061
# Honduras                        0.876           0.001                 0.105
# Hungary                          0.81          < 0.1%                 0.186
# Iceland                          0.95           0.002                 0.035
# Indonesia                       0.099           0.872                < 0.1%
# Ireland                          0.92           0.011                 0.062
# Israel                           0.02           0.186                 0.031
# Italy                           0.833           0.037                 0.124
# Jordan                          0.022           0.972                < 0.1%
# Kazakhstan                      0.248           0.704                 0.042
# Latvia                          0.558           0.001                 0.438
# Lithuania                       0.898          < 0.1%                   0.1
# Luxembourg                      0.704           0.023                 0.268
# Madagascar                      0.853            0.03                 0.069
# Malta                            0.97           0.002                 0.025
# Mexico                          0.951          < 0.1%                 0.047
# Moldova                         0.974           0.006                 0.014
# Mongolia                        0.023           0.032                 0.359
# Norway                          0.847           0.037                 0.101
# Pakistan                        0.016           0.964                < 0.1%
# Paraguay                        0.969          < 0.1%                 0.011
# Peru                            0.955          < 0.1%                  0.03
# Poland                          0.943          < 0.1%                 0.056
# Portugal                        0.938           0.006                 0.044
# Romania                         0.995           0.003                 0.001
# Slovenia                        0.784           0.036                  0.18
# Spain                           0.786           0.021                  0.19
# Sweden                          0.672           0.046                  0.27
# Switzerland                     0.813           0.055                 0.119
# Thailand                        0.009           0.055                 0.003
# Tunisia                         0.002           0.995                 0.002
# Turkey                          0.004            0.98                 0.012
# United States                   0.783           0.009                 0.164
# Ukraine                         0.838           0.012                 0.147
# United Kingdom                  0.711           0.044                 0.213
# Uruguay                         0.579          < 0.1%                 0.407
# Vietnam                         0.082           0.002                 0.296
# Zambia                          0.976           0.005                 0.005
#
#                     Percent Hindu  Percent Buddhist  Percent Folk Religions  \
# Country/Region
# Argentina                  < 0.1%            < 0.1%                   0.008
# Armenia                    < 0.1%            < 0.1%                  < 0.1%
# Australia                   0.014             0.027                   0.007
# Austria                    < 0.1%             0.002                  < 0.1%
# Belarus                    < 0.1%            < 0.1%                  < 0.1%
# Belgium                    < 0.1%             0.002                   0.002
# Bulgaria                   < 0.1%            < 0.1%                  < 0.1%
# Canada                      0.014             0.008                   0.012
# China                      < 0.1%             0.182                   0.219
# Costa Rica                 < 0.1%            < 0.1%                   0.008
# Croatia                    < 0.1%            < 0.1%                  < 0.1%
# Cyprus                     < 0.1%             0.002                  < 0.1%
# Denmark                     0.004             0.002                  < 0.1%
# Dominican Republic         < 0.1%            < 0.1%                   0.009
# Ecuador                    < 0.1%            < 0.1%                   0.003
# El Salvador                < 0.1%            < 0.1%                   0.005
# Estonia                    < 0.1%            < 0.1%                  < 0.1%
# Finland                    < 0.1%            < 0.1%                  < 0.1%
# France                     < 0.1%             0.005                   0.003
# Georgia                    < 0.1%            < 0.1%                  < 0.1%
# Germany                    < 0.1%             0.003                  < 0.1%
# Greece                      0.001            < 0.1%                   0.001
# Honduras                   < 0.1%             0.001                   0.011
# Hungary                    < 0.1%            < 0.1%                  < 0.1%
# Iceland                     0.003             0.004                   0.005
# Indonesia                   0.017             0.007                   0.003
# Ireland                     0.002             0.002                   0.002
# Israel                     < 0.1%             0.003                   0.002
# Italy                       0.001             0.002                   0.001
# Jordan                      0.001             0.004                  < 0.1%
# Kazakhstan                 < 0.1%             0.002                   0.003
# Latvia                     < 0.1%            < 0.1%                  < 0.1%
# Lithuania                  < 0.1%            < 0.1%                  < 0.1%
# Luxembourg                 < 0.1%            < 0.1%                  < 0.1%
# Madagascar                 < 0.1%            < 0.1%                   0.045
# Malta                       0.002            < 0.1%                  < 0.1%
# Mexico                     < 0.1%            < 0.1%                  < 0.1%
# Moldova                    < 0.1%            < 0.1%                  < 0.1%
# Mongolia                   < 0.1%             0.551                   0.035
# Norway                      0.005             0.006                  < 0.1%
# Pakistan                    0.019            < 0.1%                  < 0.1%
# Paraguay                   < 0.1%            < 0.1%                   0.017
# Peru                       < 0.1%             0.002                    0.01
# Poland                     < 0.1%            < 0.1%                  < 0.1%
# Portugal                    0.001             0.006                   0.005
# Romania                    < 0.1%            < 0.1%                  < 0.1%
# Slovenia                   < 0.1%            < 0.1%                  < 0.1%
# Spain                      < 0.1%            < 0.1%                  < 0.1%
# Sweden                      0.002             0.004                   0.002
# Switzerland                 0.004             0.004                  < 0.1%
# Thailand                    0.001             0.932                  < 0.1%
# Tunisia                    < 0.1%            < 0.1%                  < 0.1%
# Turkey                     < 0.1%            < 0.1%                  < 0.1%
# United States               0.006             0.012                   0.002
# Ukraine                    < 0.1%            < 0.1%                  < 0.1%
# United Kingdom              0.013             0.004                   0.003
# Uruguay                    < 0.1%            < 0.1%                   0.008
# Vietnam                    < 0.1%             0.164                   0.453
# Zambia                      0.001            < 0.1%                   0.003
#
#                     Percent Other Religions  Percent Jewish  \
# Country/Region
# Argentina                             0.003           0.005
# Armenia                               0.001          < 0.1%
# Australia                             0.008           0.005
# Austria                               0.001           0.002
# Belarus                              < 0.1%          < 0.1%
# Belgium                              < 0.1%           0.003
# Bulgaria                             < 0.1%          < 0.1%
# Canada                                0.009            0.01
# China                                 0.007          < 0.1%
# Costa Rica                            0.003          < 0.1%
# Croatia                              < 0.1%          < 0.1%
# Cyprus                               < 0.1%          < 0.1%
# Denmark                              < 0.1%          < 0.1%
# Dominican Republic                    0.001          < 0.1%
# Ecuador                              < 0.1%          < 0.1%
# El Salvador                           0.003          < 0.1%
# Estonia                              < 0.1%           0.001
# Finland                              < 0.1%          < 0.1%
# France                                0.002           0.005
# Georgia                              < 0.1%          < 0.1%
# Germany                               0.001           0.003
# Greece                               < 0.1%          < 0.1%
# Honduras                              0.006          < 0.1%
# Hungary                              < 0.1%           0.001
# Iceland                               0.002          < 0.1%
# Indonesia                             0.001          < 0.1%
# Ireland                              < 0.1%          < 0.1%
# Israel                                0.001           0.756
# Italy                                < 0.1%          < 0.1%
# Jordan                               < 0.1%          < 0.1%
# Kazakhstan                            0.001          < 0.1%
# Latvia                                0.002          < 0.1%
# Lithuania                            < 0.1%          < 0.1%
# Luxembourg                            0.003           0.001
# Madagascar                           < 0.1%          < 0.1%
# Malta                                < 0.1%          < 0.1%
# Mexico                               < 0.1%          < 0.1%
# Moldova                              < 0.1%           0.006
# Mongolia                             < 0.1%          < 0.1%
# Norway                                0.002          < 0.1%
# Pakistan                             < 0.1%          < 0.1%
# Paraguay                              0.002          < 0.1%
# Peru                                  0.003          < 0.1%
# Poland                               < 0.1%          < 0.1%
# Portugal                             < 0.1%          < 0.1%
# Romania                              < 0.1%          < 0.1%
# Slovenia                             < 0.1%          < 0.1%
# Spain                                < 0.1%           0.001
# Sweden                                0.002           0.001
# Switzerland                           0.001           0.003
# Thailand                             < 0.1%          < 0.1%
# Tunisia                              < 0.1%          < 0.1%
# Turkey                                0.002          < 0.1%
# United States                         0.006           0.018
# Ukraine                              < 0.1%           0.001
# United Kingdom                        0.008           0.005
# Uruguay                               0.003           0.003
# Vietnam                               0.004          < 0.1%
# Zambia                                0.009          < 0.1%
#
#                     2010 Country Population      Continent
# Country/Region
# Argentina                          40410000  South America
# Armenia                             3090000         Europe
# Australia                          22270000        Oceania
# Austria                             8390000         Europe
# Belarus                             9600000         Europe
# Belgium                            10710000         Europe
# Bulgaria                            7490000         Europe
# Canada                             34020000  North America
# China                            1341340000           Asia
# Costa Rica                          4660000  North America
# Croatia                             4400000         Europe
# Cyprus                              1100000         Europe
# Denmark                             5550000         Europe
# Dominican Republic                  9930000  North America
# Ecuador                            14460000  South America
# El Salvador                         6190000  North America
# Estonia                             1340000         Europe
# Finland                             5360000         Europe
# France                             62790000         Europe
# Georgia                             4350000         Europe
# Germany                            82300000         Europe
# Greece                             11360000         Europe
# Honduras                            7600000  North America
# Hungary                             9980000         Europe
# Iceland                              320000         Europe
# Indonesia                         239870000           Asia
# Ireland                             4470000         Europe
# Israel                              7420000           Asia
# Italy                              60550000         Europe
# Jordan                              6190000           Asia
# Kazakhstan                         16030000           Asia
# Latvia                              2250000         Europe
# Lithuania                           3320000         Europe
# Luxembourg                           510000         Europe
# Madagascar                         20710000         Africa
# Malta                                420000         Europe
# Mexico                            113420000  North America
# Moldova                             3570000         Europe
# Mongolia                            2760000           Asia
# Norway                              4880000         Europe
# Pakistan                          173590000           Asia
# Paraguay                            6450000  South America
# Peru                               29080000  South America
# Poland                             38280000         Europe
# Portugal                           10680000         Europe
# Romania                            21490000         Europe
# Slovenia                            2030000         Europe
# Spain                              46080000         Europe
# Sweden                              9380000         Europe
# Switzerland                         7660000         Europe
# Thailand                           69120000           Asia
# Tunisia                            10480000         Africa
# Turkey                             72750000           Asia
# United States                     310380000  North America
# Ukraine                            45450000         Europe
# United Kingdom                     62040000         Europe
# Uruguay                             3370000  South America
# Vietnam                            87850000           Asia
# Zambia                             13090000         Africa
#
# [59 rows x 107 columns]

# %%
#Europe
europe = pd.read_csv('Europe.csv')
europe_names = list(europe['State'])

#Asia
asia = pd.read_csv('Asia.csv')
asia_names = list(asia['Name'])

#South America
southamerica = pd.read_csv('SouthAmerica.csv')
southamerica_names = list(southamerica['Country'])

#North America
northamerica = pd.read_csv('NorthAmerica.csv')
northamerica_names = list(northamerica['Country'])

#Oceania
oceania = pd.read_csv('Oceania.csv')
oceania_names = list(oceania['Country'])

#Africa
africa = pd.read_csv('Africa.csv')
africa_names = list(africa['Country'])

#Continent
Continent = np.empty(len(religion), dtype='str')
Country = list(religion['Country'])

for i, c in enumerate(Country):
    if c in europe_names:
        Continent[i] = 'E'
    elif c in asia_names:
        Continent[i] = 'A'
    elif c in northamerica_names:
        Continent[i] = 'NA'
    elif c in southamerica_names:
        Continent[i] = 'SA'
    elif c in oceania_names:
        Continent[i] = 'O'
    elif c in africa_names:
        Continent[i] = 'AF'
    else:
        pass

religion.insert(1, "Continent", Continent.reshape(-1,1), True)

# %%
X.loc[:,'SP.POP.TOTL']
# Out:
# Country/Region
# Argentina             4.449450e+07
# Armenia               2.951776e+06
# Australia             2.498269e+07
# Austria               8.840521e+06
# Belarus               9.483499e+06
# Belgium               1.143326e+07
# Bulgaria              7.025037e+06
# Canada                3.705776e+07
# China                 1.392730e+09
# Costa Rica            4.999441e+06
# Croatia               4.087843e+06
# Cyprus                1.189265e+06
# Denmark               5.793636e+06
# Dominican Republic    1.062716e+07
# Ecuador               1.708436e+07
# El Salvador           6.420744e+06
# Estonia               1.321977e+06
# Finland               5.515525e+06
# France                6.697711e+07
# Georgia               3.726549e+06
# Germany               8.290578e+07
# Greece                1.073173e+07
# Honduras              9.587522e+06
# Hungary               9.775564e+06
# Iceland               3.527210e+05
# Indonesia             2.676634e+08
# Ireland               4.867309e+06
# Israel                8.882800e+06
# Italy                 6.042176e+07
# Jordan                9.956011e+06
# Kazakhstan            1.827243e+07
# Latvia                1.927174e+06
# Lithuania             2.801543e+06
# Luxembourg            6.079500e+05
# Madagascar            2.626237e+07
# Malta                 4.846300e+05
# Mexico                1.261908e+08
# Moldova               2.706049e+06
# Mongolia              3.170208e+06
# Norway                5.311916e+06
# Pakistan              2.122150e+08
# Paraguay              6.956071e+06
# Peru                  3.198926e+07
# Poland                3.797475e+07
# Portugal              1.028382e+07
# Romania               1.946614e+07
# Slovenia              2.073894e+06
# Spain                 4.679654e+07
# Sweden                1.017521e+07
# Switzerland           8.513227e+06
# Thailand              6.942852e+07
# Tunisia               1.156520e+07
# Turkey                8.231972e+07
# United States         3.266875e+08
# Ukraine               4.462252e+07
# United Kingdom        6.646034e+07
# Uruguay               3.449299e+06
# Vietnam               9.554040e+07
# Zambia                1.735182e+07
# Name: SP.POP.TOTL, dtype: float64

# %%
y.iloc[:,-1]/X.loc[:,'SP.POP.TOTL']
# Out:
# Country/Region
# Argentina             0.000064
# Armenia               0.000437
# Australia             0.000262
# Austria               0.001668
# Belarus               0.000504
# Belgium               0.003367
# Bulgaria              0.000127
# Canada                0.000962
# China                 0.000060
# Costa Rica            0.000132
# Croatia               0.000458
# Cyprus                0.000645
# Denmark               0.001308
# Dominican Republic    0.000440
# Ecuador               0.000554
# El Salvador           0.000031
# Estonia               0.001156
# Finland               0.000686
# France                0.002301
# Georgia               0.000106
# Germany               0.001751
# Greece                0.000208
# Honduras              0.000049
# Hungary               0.000196
# Iceland               0.005021
# Indonesia             0.000025
# Ireland               0.003133
# Israel                0.001519
# Italy                 0.002962
# Jordan                0.000042
# Kazakhstan            0.000092
# Latvia                0.000377
# Lithuania             0.000463
# Luxembourg            0.005839
# Madagascar            0.000005
# Malta                 0.000881
# Mexico                0.000059
# Moldova               0.000914
# Mongolia              0.000010
# Norway                0.001332
# Pakistan              0.000039
# Paraguay              0.000030
# Peru                  0.000489
# Poland                0.000245
# Portugal              0.001965
# Romania               0.000449
# Slovenia              0.000641
# Spain                 0.004245
# Sweden                0.001414
# Switzerland           0.003258
# Thailand              0.000040
# Tunisia               0.000076
# Turkey                0.001048
# United States         0.002324
# Ukraine               0.000122
# United Kingdom        0.001823
# Uruguay               0.000150
# Vietnam               0.000003
# Zambia                0.000004
# dtype: float64

# %%
nonZero = []
for country in y.index:
    for date in y.columns:
        if y.loc[country,date] != 0:
            index = y.columns.get_loc(date)
            nonZero.append(index)
            break
frac = y.iloc[:,-1]/X.loc[:,'SP.POP.TOTL']
fig = plt.figure(figsize=[12,6])
plt.plot(nonZero,frac,'.')
plt.title('First Cases in each country')
plt.xlabel('Days since first case in Wuhan')
# Out:
# Text(0.5, 0, 'Days since first case in Wuhan')
